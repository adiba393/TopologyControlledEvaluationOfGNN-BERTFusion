# %% [markdown]
# # Demo - end-to-end music context inference
#
# Loads the trained Task 3 fusion model and the Task 4 contrastive encoder, then runs one clip through the full pipeline (audio -> graphs -> GNN+BERT -> context tags + caption retrieval).
#
# Run the master notebook `../../GNN_BERT_Music_Context_Project.ipynb` first so the checkpoints in `results/checkpoints/` exist.

# %%
import sys, torch
sys.path.append('../src')
from pathlib import Path

CKPT = Path('../results/checkpoints')
print('available checkpoints:', [p.name for p in CKPT.glob('*.pt')])

# %%
# The `infer_music_context` function below is the one exported from the master notebook.
# See src/fusion_model.py and src/contrastive.py for the model definitions.
import json
print(json.dumps(json.load(open('../results/demo_inference_example.json')), indent=2)[:1500])

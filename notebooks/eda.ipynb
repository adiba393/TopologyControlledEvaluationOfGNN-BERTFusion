# %% [markdown]
# # EDA - corpora, labels and graph structure
#
# Regenerated from `results/metrics.json`.

# %%
import json, pandas as pd
m = json.load(open('../results/metrics.json'))
print(json.dumps(m['data'], indent=2)[:2000])

# %%
pd.DataFrame(m['data']['graph_stats']).round(3)
